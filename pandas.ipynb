# %% [markdown]
# <a href="https://colab.research.google.com/github/Shavkatov-dev/ai_foundation/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas

# %%
import pandas as pd

# %%
print(pd.__version__)
# Out:
# 2.2.2

# %%
mydataset = {
  'cars': ["BMW", "Volvo", "Ford"],
  'counts': [3, 7, 2]
}

df = pd.DataFrame(mydataset)

print(df)
print("=========")
# Out:
#     cars  counts
# 0    BMW       3
# 1  Volvo       7
# 2   Ford       2
# ...

# %%
mydataset = {
  'cars': ["BMW", "Volvo", "Ford", "Tesla", "Ford", "BMW"],
  'counts': [3, 7, 2, 4, 5, 6]
}

df = pd.DataFrame(mydataset)

print(df)
print("=========")
# Out:
#     cars  counts
# 0    BMW       3
# 1  Volvo       7
# 2   Ford       2
# 3  Tesla       4
# 4   Ford       5
# 5    BMW       6
# ...

# %%
df.head() # top-to-bottom (default 5 rows)
# Out:
#     cars  counts
# 0    BMW       3
# 1  Volvo       7
# 2   Ford       2
# 3  Tesla       4
# 4   Ford       5

# %%
df.head(8)
# Out:
#     cars  counts
# 0    BMW       3
# 1  Volvo       7
# 2   Ford       2
# 3  Tesla       4
# 4   Ford       5
# 5    BMW       6

# %%
df.tail(2) #bottom-to-top (default 5 rows)
# Out:
#    cars  counts
# 4  Ford       5
# 5   BMW       6

# %%
df.shape
# Out:
# (6, 2)

# %%
df.columns
# Out:
# Index(['cars', 'counts'], dtype='object')

# %%
df.dtypes
# Out:
# cars      object
# counts     int64
# dtype: object

# %%
print(df)
# Out:
#     cars  counts
# 0    BMW       3
# 1  Volvo       7
# 2   Ford       2
# 3  Tesla       4
# 4   Ford       5
# 5    BMW       6

# %%
df.describe(include="all") # numerical columns only
# Out:
#        cars    counts
# count     6  6.000000
# unique    4       NaN
# top     BMW       NaN
# freq      2       NaN
# mean    NaN  4.500000
# std     NaN  1.870829
# min     NaN  2.000000
# 25%     NaN  3.250000
# 50%     NaN  4.500000
# 75%     NaN  5.750000
# max     NaN  7.000000

# %%
df.iloc[1: 4] #row select
# Out:
#     cars  counts
# 1  Volvo       7
# 2   Ford       2
# 3  Tesla       4

# %%
df.loc[:, "counts"]
# Out:
# 0    3
# 1    7
# 2    2
# 3    4
# 4    5
# 5    6
# Name: counts, dtype: int64

# %%
df["counts"] > 3 #boolean
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4     True
# 5     True
# Name: counts, dtype: bool

# %%
df.mean(numeric_only=True)
df["counts"].mean[]
# Out:
# counts    4.5
# dtype: float64

# %%
df.sum()
# Out:
# cars      BMWVolvoFordTeslaFordBMW
# counts                          27
# dtype: object

# %%
df.min()
# Out:
# cars      BMW
# counts      2
# dtype: object

# %%
df.max()
# Out:
# cars      Volvo
# counts        7
# dtype: object

# %%
df.median(numeric_only=True)
# Out:
# counts    4.5
# dtype: float64

# %%
df.count()
# Out:
# cars      6
# counts    6
# dtype: int64

# %%
df.std(numeric_only=True)
# Out:
# counts    1.870829
# dtype: float64

# %%
data_with_missing = {
    "cars": ["BMW", "Volvo", None, "Tesla", "Ferrari", None],
    "counts": [3, 7, None, 8, 1, None]
}

df_missing = pd.DataFrame(data_with_missing)
print(df_missing)
# Out:
#       cars  counts
# 0      BMW     3.0
# 1    Volvo     7.0
# 2     None     NaN
# 3    Tesla     8.0
# 4  Ferrari     1.0
# 5     None     NaN

# %%
df_missing.isnull().sum()
# Out:
# cars      2
# counts    2
# dtype: int64

# %%
df_missing.dropna(subset=["cars"])
# Out:
#       cars  counts
# 0      BMW     3.0
# 1    Volvo     7.0
# 3    Tesla     8.0
# 4  Ferrari     1.0

# %%
df_missing.fillna({"cars":"unknown", "counts": 0})
# Out:
#       cars  counts
# 0      BMW     3.0
# 1    Volvo     7.0
# 2  unknown     0.0
# 3    Tesla     8.0
# 4  Ferrari     1.0
# 5  unknown     0.0

# %%
df = pd.read_csv("Titanic-Dataset.csv")

df.tail(35)

#df = pd.rad_excel("Titanic-Dataset.xlsx")
#df = pd.read_json("Titanic-Dataset.xlsx")
# Out:
#      PassengerId  Survived  Pclass  \
# 856          857         1       1
# 857          858         1       1
# 858          859         1       3
# 859          860         0       3
# 860          861         0       3
# 861          862         0       2
# 862          863         1       1
# 863          864         0       3
# 864          865         0       2
# 865          866         1       2
# 866          867         1       2
# 867          868         0       1
# 868          869         0       3
# 869          870         1       3
# 870          871         0       3
# 871          872         1       1
# 872          873         0       1
# 873          874         0       3
# 874          875         1       2
# 875          876         1       3
# 876          877         0       3
# 877          878         0       3
# 878          879         0       3
# 879          880         1       1
# 880          881         1       2
# ...

# %%
df.to_excel("Output.xlsx")

# %%
df = pd.read_excel("Output.xlsx")
df.head()
# Out:
#    Unnamed: 0  PassengerId  Survived  Pclass  \
# 0           0            1         0       3
# 1           1            2         1       1
# 2           2            3         1       3
# 3           3            4         1       1
# 4           4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
# series => 1D

cars = pd.Series(["BMW", "Tesla", "None"])
print(cars)
# Out:
# 0      BMW
# 1    Tesla
# 2     None
# dtype: object

# %%
cars_series = data_with_missing['cars']
print(cars_series)
# Out:
# ['BMW', 'Volvo', None, 'Tesla', 'Ferrari', None]
